# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.model_selection import train_test_split
plt.rcParams["figure.figsize"] = (10,8)


import statsmodels.formula.api as smf


from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn import tree



from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data/dflimpio.csv", index_col = 0)
df.head()
# Out:
#                 Offer Accepted     Reward Income Level  \
# Customer Number
# 1                           No  Air Miles         High
# 2                           No  Air Miles       Medium
# 3                           No  Air Miles         High
# 4                           No  Air Miles       Medium
# 5                           No  Air Miles       Medium
#
#                  Non credit card accounts Credit Rating  Credt cards held  \
# Customer Number
# 1                                       1          High                 2
# 2                                       1        Medium                 2
# 3                                       2        Medium                 2
# 4                                       2          High                 1
# 5                                       1        Medium                 2
#
#                  Homes Owned  Household Size  Average Balance
# Customer Number
# 1                          1               4          1160.75
# 2                          2               5           147.25
# 3                          1               2           276.50
# 4                          1               4          1219.00
# 5                          1               6          1211.00

# %%
df_modelo = df.select_dtypes(include=np.number)

# %%
X = df.drop('Offer Accepted', axis =1)
y = df['Offer Accepted']


X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

# %%
param = {"max_depth": [4, 5, 6, 7],
        "min_samples_split": [10, 50, 100, 300],
        "max_features": [7, 11]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
regressor = DecisionTreeRegressor(random_state = 0)

# %%
param = {"max_depth": [4, 5, 6, 7],
        "min_samples_split": [10, 50, 100, 300],
        "max_features": [7, 11]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
# %time
gs.fit(X_train, y_train)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# [CV 1/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=7, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=7, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=7, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=7, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=11, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=11, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=11, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=11, min_samples_split=300;, score=(train=nan, test=nan) total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13268/3560237359.py in <module>
#       1 get_ipython().run_line_magic('time', '')
# ----> 2 gs.fit(X_train, y_train)
#
# ~\miniconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# ~\miniconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# ~\miniconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# ~\miniconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# ~\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    2070
#    2071     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072         return np.asarray(self._values, dtype=dtype)
#    2073
#    2074     def __array_wrap__(
#
# ValueError: could not convert string to float: 'Cash Back'

# %%
best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=4, max_features=7, min_samples_split=10)
